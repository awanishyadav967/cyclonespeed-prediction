# %% [markdown]
# <a href="https://colab.research.google.com/github/Sparshj8287/Cyclonet/blob/master/Cyclone_Project_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json

api_token = {"username":"sparshjain8287","key":"ec7b20617be61dd75d5c92c221b97e06"}

import json

with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(api_token, file)

# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# The syntax of the command is incorrect.
# touch: cannot touch '~/.kaggle/kaggle.json': No such file or directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 api_token = {"username":"sparshjain8287","key":"ec7b20617be61dd75d5c92c221b97e06"}
#       6 import json
# ----> 8 with open('/root/.kaggle/kaggle.json', 'w') as file:
#       9   json.dump(api_token, file)
#      11 get_ipython().system('chmod 600 ~/.kaggle/kaggle.json')
#
# File c:\Users\Avanish\anaconda4\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.kaggle/kaggle.json'

# %%
# !kaggle datasets download -d sshubam/insat3d-infrared-raw-cyclone-images-20132021
# Out:
# Downloading insat3d-infrared-raw-cyclone-images-20132021.zip to /content
#  62% 27.0M/43.2M [00:00<00:00, 75.2MB/s]
# 100% 43.2M/43.2M [00:00<00:00, 99.2MB/s]

# %%
# !unzip /content/insat3d-infrared-raw-cyclone-images-20132021.zip
# Out:
# Archive:  /content/insat3d-infrared-raw-cyclone-images-20132021.zip
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/101.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/102.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/106.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/111.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/112.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/115.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/118.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/119.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/128.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/25.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/27.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/28.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/30(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/30.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/31.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/32(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/32.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/33(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/33(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/33.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/34(!).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/34.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/35(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/35(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/35(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/35.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/36(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/36(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/36(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/36.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/37.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/38.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/39.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/40(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/40(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/40(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/40.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/41.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/42(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/42.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/43(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/43.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/44(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/44(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/44(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/44.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/45(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/45(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/45(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/45(4).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/45.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/46(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/46(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/46(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/46.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/47(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/47(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/47(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/47(4).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/47.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/48(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/48(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/48(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/48.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/49(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/49(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/49.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/50(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/50(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/50.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/51(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/51.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/52(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/52.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/53(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/53(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/53(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/53.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/54.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/55(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/55(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/55.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/56.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/57(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/57(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/57.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/58(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/58.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/59(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/59(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/59.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/59_LUBAN.png
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/60(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/60(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/60.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/61(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/61(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/61.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/62.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/63(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/63(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/63.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/64(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/64(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/64.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/65(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/65(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/65(3).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/65.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/66.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/67(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/67.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/67.png
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/68(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/68.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/69(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/69.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/70.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/73.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/74(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/74(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/74.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/75.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/77(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/77.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/81.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/82(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/82.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/83(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/83.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/84(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/84.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/85(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/85(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/85.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/86(1).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/86(2).jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/86.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/87.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/91.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/94.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/98.jpeg
#   inflating: insat3d_for_reference_ds/CYCLONE_DATASET/99.jpeg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/101.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/102.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/106.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/111.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/112.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/115.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/118.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/119.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/128.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/25.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/27.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/28.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/30(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/30.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/31.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/32(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/32.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/33(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/33(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/33.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/34(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/34.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/35(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/35(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/35(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/35.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/36(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/36(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/36(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/36.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/37.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/38.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/39.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/40(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/40(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/40(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/40.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/41.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/42(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/42.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/43(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/43.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/44(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/44(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/44(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/44.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/45(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/45(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/45(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/45(4).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/45.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/46(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/46(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/46.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/47(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/47(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/47(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/47(4).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/47.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/48(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/48(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/48(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/48.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/49(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/49(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/49.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/50(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/50(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/50.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/51(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/51.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/52(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/52.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/53(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/53(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/53(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/53.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/54.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/55(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/55.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/56.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/57(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/57(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/57.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/58(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/58.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/59(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/59(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/59(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/59.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/60(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/60(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/60.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/61(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/61(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/61.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/62.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/63(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/63(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/63.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/64(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/64(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/64.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/65(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/65(3).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/65.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/67(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/67.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/68.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/69(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/69.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/70.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/73.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/74(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/74(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/74.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/75.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/77(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/77.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/81(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/81.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/82(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/82.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/83(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/84(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/84.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/85(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/85(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/85.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/86(1).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/86(2).jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/86.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/87.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/94.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/98.jpg
#   inflating: insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/99.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/101.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/102.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/106.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/111.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/112.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/115.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/118.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/119.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/128.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/25.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/27.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/28.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/30(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/30.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/31.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/32(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/32.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/33(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/33(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/33.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/34(!).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/34.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/35(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/35(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/35(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/35.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/36(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/36(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/36(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/36.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/37.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/38.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/39.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/40(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/40(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/40(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/40.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/41.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/42(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/42.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/43(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/43.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/44(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/44(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/44(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/44.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/45(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/45(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/45(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/45(4).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/45.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/46(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/46(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/46.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/47(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/47(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/47(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/47(4).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/47.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/48(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/48(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/48(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/48.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/49(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/49(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/49.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/50(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/50(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/50.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/51(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/51.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/52(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/52.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/53(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/53(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/53(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/53.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/54 2.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/54.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/55(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/55.JPEG
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/56.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/57(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/57(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/57.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/58(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/58.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/59(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/59(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/59.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/59_LUBAN 2.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/59_LUBAN.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/60(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/60(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/60.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/61(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/61(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/61.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/62.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/63(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/63(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/63.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/64(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/64(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/64.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/65(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/65(3).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/65.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/67 2.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/67(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/67.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/68(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/68.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/69(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/69.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/70.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/73.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/74(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/74(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/74.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/75.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/77(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/77.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/81 2.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/81.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/82(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/82.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/83(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/84 2.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/84.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/85(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/85(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/85.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/86(1).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/86(2).jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/86.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/87.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/94.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/98.jpg
#   inflating: insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL/99.jpg
#   inflating: insat_3d_ds - Sheet.csv

# %% [markdown]
# ##First we visualise the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
pd.read_csv("/content/insat_3d_ds - Sheet.csv")
# Out:
#       img_name  label
# 0       25.jpg     25
# 1       27.jpg     27
# 2       28.jpg     28
# 3       30.jpg     30
# 4    30(1).jpg     30
# ..         ...    ...
# 131    112.jpg    112
# 132    115.jpg    115
# 133    118.jpg    118
# 134    119.jpg    119
# 135    128.jpg    128
#
# [136 rows x 2 columns]

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("/content/insat3d_ir_cyclone_ds"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 1 directories and 0 images in '/content/insat3d_ir_cyclone_ds'.
# There are 0 directories and 136 images in '/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED'.

# %%
os.mkdir("test_data")

# %%
import os
import shutil
 
source = '/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED'
destination = '/content/test_data'
 
# gather all files
allfiles = os.listdir(source)
 
# iterate on all files to move them to destination folder
for f in allfiles[133:]:
    
    src_path = os.path.join(source, f)
    dst_path = os.path.join(destination, f)
    shutil.move(src_path, dst_path)

# %%
#Get the classes drammatically
import pathlib
data_dir=pathlib.Path("/content/insat3d_ir_cyclone_ds")
data_dir
# Out:
# PosixPath('/content/insat3d_ir_cyclone_ds')

# %%
#Let visualise our images 
import random
def view_random_image(target_dir):
  target_folder=target_dir
  random_image=random.sample(os.listdir(target_folder),10)
  plt.figure(figsize=(10,10))
  for i in range(10):
    img=mpimg.imread(target_folder+"/"+random_image[i])
    plt.subplot(5,2,i+1)
    plt.imshow(img)
    plt.title(random_image[i])
    plt.axis("off");#Default axis is on

# %%
view_random_image("/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED")

# %%
view_random_image("/content/insat3d_for_reference_ds/CYCLONE_DATASET")

# %%
view_random_image("/content/insat3d_raw_cyclone_ds/CYCLONE_DATASET_FINAL")

# %% [markdown]
# #Preprocess the data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train=pd.read_csv("/content/insat_3d_ds - Sheet.csv")

# %%
train_dir="/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED"
train_datagen=ImageDataGenerator(rescale=1./255)
train_data=train_datagen.flow_from_dataframe(train,train_dir,
                                             x_col='img_name',
                                             y_col="label",
                                             subset='training',
                                             target_size=(256,256),
                                             batch_size=16,
                                             class_mode="raw"
                                             )
# Out:
# Found 133 validated image filenames.
# /usr/local/lib/python3.9/dist-packages/keras/preprocessing/image.py:1137: UserWarning: Found 3 invalid image filename(s) in x_col="img_name". These filename(s) will be ignored.
#   warnings.warn(

# %% [markdown]
# #Create a model

# %%
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense,Dropout,Input
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
inputs=Input(shape=(256,256,3))
y=Conv2D(256,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(inputs)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=Conv2D(256,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=MaxPool2D()(y)

y=Conv2D(256,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=Conv2D(128,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=MaxPool2D()(y)

y=Conv2D(128,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=Conv2D(64,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=MaxPool2D()(y)

y=Conv2D(64,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=Conv2D(32,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=MaxPool2D()(y)

y=Conv2D(32,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=Conv2D(16,3,activation=None, padding="same",kernel_initializer="he_normal",kernel_regularizer=regularizers.L1L2(0.01))(y)
y=tf.keras.layers.BatchNormalization()(y)
y=tf.keras.activations.relu(y)
y=MaxPool2D()(y)

y= Flatten()(y)
outputs=Dense(1,activation='linear')(y)
model_1=Model(inputs=inputs,outputs=outputs)

# %%
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 256)     7168
#
#  batch_normalization (BatchN  (None, 256, 256, 256)    1024
#  ormalization)
#
#  tf.nn.relu (TFOpLambda)     (None, 256, 256, 256)     0
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 256)     590080
#
#  batch_normalization_1 (Batc  (None, 256, 256, 256)    1024
#  hNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 256, 256, 256)     0
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 256)    0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 256)     590080
#
#  batch_normalization_2 (Batc  (None, 128, 128, 256)    1024
#  hNormalization)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 128, 128, 256)     0
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)     295040
#
#  batch_normalization_3 (Batc  (None, 128, 128, 128)    512
#  hNormalization)
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 128, 128, 128)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       147584
#
#  batch_normalization_4 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 64, 64, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        73792
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 64, 64, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_6 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  tf.nn.relu_6 (TFOpLambda)   (None, 32, 32, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        18464
#
#  batch_normalization_7 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  tf.nn.relu_7 (TFOpLambda)   (None, 32, 32, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_8 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  tf.nn.relu_8 (TFOpLambda)   (None, 16, 16, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 16)        4624
#
#  batch_normalization_9 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  tf.nn.relu_9 (TFOpLambda)   (None, 16, 16, 16)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 1,778,961
# Trainable params: 1,776,497
# Non-trainable params: 2,464
# _________________________________________________________________

# %%
model_1.compile(loss=tf.keras.losses.mse,
                optimizer=tf.keras.optimizers.Adam(lr=0.002),
                metrics=["mse"])
early_stopping=tf.keras.callbacks.EarlyStopping(monitor="loss",patience=10,mode='min')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
history_1=model_1.fit(train_data,
                      epochs=50,callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 9/9 [==============================] - 66s 2s/step - loss: 3749.2905 - mse: 3263.6118
# Epoch 2/50
# 9/9 [==============================] - 7s 768ms/step - loss: 2688.0249 - mse: 2199.9595
# Epoch 3/50
# 9/9 [==============================] - 7s 777ms/step - loss: 1904.8313 - mse: 1415.4984
# Epoch 4/50
# 9/9 [==============================] - 7s 792ms/step - loss: 1365.4807 - mse: 875.9043
# Epoch 5/50
# 9/9 [==============================] - 7s 785ms/step - loss: 1027.3516 - mse: 538.1570
# Epoch 6/50
# 9/9 [==============================] - 7s 784ms/step - loss: 830.7203 - mse: 342.2648
# Epoch 7/50
# 9/9 [==============================] - 7s 842ms/step - loss: 770.8824 - mse: 283.4375
# Epoch 8/50
# 9/9 [==============================] - 7s 778ms/step - loss: 724.3078 - mse: 237.9283
# Epoch 9/50
# 9/9 [==============================] - 7s 831ms/step - loss: 690.6140 - mse: 205.5209
# Epoch 10/50
# 9/9 [==============================] - 7s 771ms/step - loss: 674.0974 - mse: 190.2602
# Epoch 11/50
# 9/9 [==============================] - 7s 775ms/step - loss: 622.2501 - mse: 139.7704
# Epoch 12/50
# 9/9 [==============================] - 7s 780ms/step - loss: 606.4003 - mse: 125.3210
# Epoch 13/50
# 9/9 [==============================] - 7s 776ms/step - loss: 585.3867 - mse: 105.7136
# Epoch 14/50
# 9/9 [==============================] - 7s 779ms/step - loss: 593.8271 - mse: 115.6652
# Epoch 15/50
# 9/9 [==============================] - 7s 781ms/step - loss: 592.6012 - mse: 115.9223
# Epoch 16/50
# 9/9 [==============================] - 7s 783ms/step - loss: 566.4687 - mse: 91.3553
# Epoch 17/50
# 9/9 [==============================] - 7s 782ms/step - loss: 531.4559 - mse: 58.0627
# Epoch 18/50
# 9/9 [==============================] - 7s 783ms/step - loss: 526.3901 - mse: 54.6746
# Epoch 19/50
# 9/9 [==============================] - 7s 776ms/step - loss: 515.8837 - mse: 46.0098
# Epoch 20/50
# 9/9 [==============================] - 7s 780ms/step - loss: 543.4091 - mse: 75.3584
# Epoch 21/50
# 9/9 [==============================] - 7s 778ms/step - loss: 510.3295 - mse: 44.1514
# Epoch 22/50
# 9/9 [==============================] - 7s 780ms/step - loss: 533.9155 - mse: 69.6927
# Epoch 23/50
# 9/9 [==============================] - 7s 779ms/step - loss: 528.9724 - mse: 66.7163
# Epoch 24/50
# 9/9 [==============================] - 7s 842ms/step - loss: 503.1843 - mse: 42.9411
# Epoch 25/50
# 9/9 [==============================] - 7s 780ms/step - loss: 541.6487 - mse: 83.3529
# Epoch 26/50
# 9/9 [==============================] - 7s 781ms/step - loss: 498.5578 - mse: 42.3171
# Epoch 27/50
# 9/9 [==============================] - 7s 783ms/step - loss: 497.7793 - mse: 43.7195
# Epoch 28/50
# 9/9 [==============================] - 7s 780ms/step - loss: 486.0619 - mse: 34.1144
# Epoch 29/50
# 9/9 [==============================] - 7s 771ms/step - loss: 475.6813 - mse: 25.9237
# Epoch 30/50
# 9/9 [==============================] - 7s 776ms/step - loss: 470.5743 - mse: 23.1485
# Epoch 31/50
# 9/9 [==============================] - 7s 778ms/step - loss: 488.9099 - mse: 43.6866
# Epoch 32/50
# 9/9 [==============================] - 7s 778ms/step - loss: 472.0363 - mse: 28.9920
# Epoch 33/50
# 9/9 [==============================] - 7s 836ms/step - loss: 486.4863 - mse: 45.8080
# Epoch 34/50
# 9/9 [==============================] - 7s 779ms/step - loss: 482.0922 - mse: 43.5696
# Epoch 35/50
# 9/9 [==============================] - 7s 779ms/step - loss: 455.4655 - mse: 19.4083
# Epoch 36/50
# 9/9 [==============================] - 7s 781ms/step - loss: 462.3198 - mse: 28.5722
# Epoch 37/50
# 9/9 [==============================] - 7s 779ms/step - loss: 453.5433 - mse: 22.3961
# Epoch 38/50
# 9/9 [==============================] - 7s 773ms/step - loss: 446.7944 - mse: 18.0353
# Epoch 39/50
# 9/9 [==============================] - 7s 779ms/step - loss: 445.1046 - mse: 18.8651
# Epoch 40/50
# 9/9 [==============================] - 7s 838ms/step - loss: 453.2372 - mse: 29.6433
# Epoch 41/50
# 9/9 [==============================] - 7s 781ms/step - loss: 450.4870 - mse: 29.2981
# Epoch 42/50
# 9/9 [==============================] - 7s 782ms/step - loss: 445.2857 - mse: 26.6206
# Epoch 43/50
# 9/9 [==============================] - 7s 781ms/step - loss: 442.1131 - mse: 25.9860
# Epoch 44/50
# 9/9 [==============================] - 7s 774ms/step - loss: 433.3628 - mse: 19.8710
# Epoch 45/50
# 9/9 [==============================] - 7s 778ms/step - loss: 424.0723 - mse: 13.1302
# Epoch 46/50
# 9/9 [==============================] - 7s 840ms/step - loss: 423.0648 - mse: 14.9058
# Epoch 47/50
# 9/9 [==============================] - 7s 781ms/step - loss: 437.1326 - mse: 31.4646
# Epoch 48/50
# 9/9 [==============================] - 7s 774ms/step - loss: 415.3917 - mse: 12.3944
# Epoch 49/50
# 9/9 [==============================] - 7s 774ms/step - loss: 413.6482 - mse: 13.3187
# Epoch 50/50
# 9/9 [==============================] - 7s 773ms/step - loss: 410.2502 - mse: 12.4838

# %%
plt.plot(history_1.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
def load_and_prep_image(filename, img_shape=256):
  
  img = tf.io.read_file(filename)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.resize(img, size = [img_shape, img_shape])
  img = img/255.
  return img

# %%
def pred_and_plot(model, filename):
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))
  
# Plot the image and predicted value
  plt.imshow(img)
  plt.title(f"Prediction: {pred}")
  plt.axis(False);

# %%
pred_and_plot(model_1,"/content/test_data/35.jpg")
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
pred_and_plot(model_1,"/content/test_data/36(2).jpg")
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
pred_and_plot(model_1,"/content/test_data/47(2).jpg")
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
pred_and_plot(model_1,"/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/69.jpg")
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
pred_and_plot(model_1,"/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/85(2).jpg")
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
pred_and_plot(model_1,"/content/insat3d_ir_cyclone_ds/CYCLONE_DATASET_INFRARED/94.jpg")
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
import joblib

# Assuming 'model_1' is your trained TensorFlow/Keras model
filename = "Trained_model.joblib"
joblib.dump(model_1, filename)

# %%
from google.colab import files

files.download('Trained_model.joblib')
